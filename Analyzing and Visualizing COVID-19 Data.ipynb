# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv('/Users/sandipdudhalkar/Downloads/archive (3) 2/country_wise_latest.csv')
df2= pd.read_csv('/Users/sandipdudhalkar/Downloads/archive (3) 2/covid_19_clean_complete.csv')

# %%
df1
df2
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
# concate the two data set
combined_df = pd.concat([df1, df2], ignore_index=True)
combined_df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796      106.0        10.0
# 1        Albania       4880     144       2745    1991      117.0         6.0
# 2        Algeria      27973    1163      18837    7973      616.0         8.0
# 3        Andorra        907      52        803      52       10.0         0.0
# 4         Angola        950      41        242     667       18.0         1.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           18.0                3.50                  69.49
# 1           63.0                2.95                  56.25
# 2          749.0                4.16                  67.34
# 3            0.0                5.73                  88.53
# 4            0.0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04              35526.0          737.0
# ...

# %%
# used to fill na values 
combined_df.fillna('0', inplace=True)
combined_df
# Out:
#               Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0                Afghanistan      36263    1269      25198    9796      106.0
# 1                    Albania       4880     144       2745    1991      117.0
# 2                    Algeria      27973    1163      18837    7973      616.0
# 3                    Andorra        907      52        803      52       10.0
# 4                     Angola        950      41        242     667       18.0
# ...                      ...        ...     ...        ...     ...        ...
# 49250  Sao Tome and Principe        865      14        734     117        0.0
# 49251                  Yemen       1691     483        833     375        0.0
# 49252                Comoros        354       7        328      19        0.0
# 49253             Tajikistan       7235      60       6028    1147        0.0
# 49254                Lesotho        505      12        128     365        0.0
#
# ...

# %%
#used to show header of data
combined_df.head()
# Out:
#   Country/Region  Confirmed  Deaths    Recovered  Active  New cases  \
# 0    Afghanistan      36263    1269  9241.509434    9796        106
# 1        Albania       4880     144  1701.709402    1991        117
# 2        Algeria      27973    1163  1294.318182    7973        616
# 3        Andorra        907      52   520.000000      52         10
# 4         Angola        950      41  3705.555556     667         18
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
#drop na vlaues

combined_df = df.dropna()
combined_df
# Out:
#          Country/Region  Confirmed  Deaths    Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269  9241.509434    9796        106
# 1               Albania       4880     144  1701.709402    1991        117
# 2               Algeria      27973    1163  1294.318182    7973        616
# 3               Andorra        907      52   520.000000      52         10
# 4                Angola        950      41  3705.555556     667         18
# ..                  ...        ...     ...          ...     ...        ...
# 182  West Bank and Gaza      10621      78  4467.763158    6791        152
# 183      Western Sahara         10       1          inf       1          0
# 184               Yemen       1691     483  3750.000000     375         10
# 185              Zambia       4552     140  2249.295775    1597         71
# 186            Zimbabwe       2704      36  1107.291667    2126        192
#
# ...

# %%
#Plot Total Cases Over Time for a Specific Country
top_countries = df.groupby("Country/Region")["New cases"].max().nlargest(10)
plt.figure(figsize=(12,6))
sns.barplot(x=top_countries.index, y=top_countries.values, palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Country")
plt.ylabel("Total Cases")
plt.title("Top 10 Countries with Highest COVID-19 Cases")
plt.show()

# %%
#Heatmap for Correlation Between Data Features

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
